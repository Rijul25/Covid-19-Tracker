# %%
import pandas as pd
import os
import shutil

# %%
#create the data for positive samples(GITHUB)
FILE_PATH = "./Downloads/chest_xray_github/covid-chestxray-dataset/metadata.csv"
IMAGES_PATH = "./Downloads/chest_xray_github/covid-chestxray-dataset/images/"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (360, 28)

# %%
df.head()
# Out:
#    patientid  offset sex   age   finding survival intubated  \
# 0          2     0.0   M  65.0  COVID-19        Y       NaN
# 1          2     3.0   M  65.0  COVID-19        Y       NaN
# 2          2     5.0   M  65.0  COVID-19        Y       NaN
# 3          2     6.0   M  65.0  COVID-19        Y       NaN
# 4          4     0.0   F  52.0  COVID-19      NaN       NaN
#
#   intubation_present went_icu needed_supplemental_O2     ...      \
# 0                NaN      NaN                    NaN     ...
# 1                NaN      NaN                    NaN     ...
# 2                NaN      NaN                    NaN     ...
# 3                NaN      NaN                    NaN     ...
# 4                NaN      NaN                    NaN     ...
#
#                date                                           location  \
# 0  January 22, 2020        Cho Ray Hospital, Ho Chi Minh City, Vietnam
# 1  January 25, 2020        Cho Ray Hospital, Ho Chi Minh City, Vietnam
# ...

# %%
TARGET_DIR = "./covid_dataset/coivd"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Folder created")

# %%
cnt = 0

for (i,row) in df.iterrows():
    if row["finding"] == "COVID-19" and row["view"]=="PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("moving images",cnt)
        cnt += 1
        
print(cnt)
# Out:
# moving images 0
# moving images 1
# moving images 2
# moving images 3
# moving images 4
# moving images 5
# moving images 6
# moving images 7
# moving images 8
# moving images 9
# moving images 10
# moving images 11
# moving images 12
# moving images 13
# moving images 14
# moving images 15
# moving images 16
# moving images 17
# moving images 18
# moving images 19
# moving images 20
# moving images 21
# moving images 22
# moving images 23
# moving images 24
# moving images 25
# moving images 26
# moving images 27
# moving images 28
# moving images 29
# moving images 30
# moving images 31
# moving images 32
# moving images 33
# moving images 34
# moving images 35
# moving images 36
# moving images 37
# moving images 38
# moving images 39
# moving images 40
# moving images 41
# moving images 42
# moving images 43
# moving images 44
# moving images 45
# moving images 46
# moving images 47
# moving images 48
# moving images 49
# moving images 50
# moving images 51
# moving images 52
# ...

# %%
#now we will sample images from the kaggle dataset
import random

KAGGLE_FILE_PATH = "./Downloads/chest_xray/train/NORMAL/"
TARGET_NORMAL_DIR = "./covid_dataset/normal/"

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)

# %%
image_names
# Out:
# ['NORMAL2-IM-0927-0001.jpeg',
#  'NORMAL2-IM-1056-0001.jpeg',
#  'IM-0427-0001.jpeg',
#  'NORMAL2-IM-1260-0001.jpeg',
#  'IM-0656-0001-0001.jpeg',
#  'IM-0561-0001.jpeg',
#  'NORMAL2-IM-1110-0001.jpeg',
#  'IM-0757-0001.jpeg',
#  'NORMAL2-IM-1326-0001.jpeg',
#  'NORMAL2-IM-0736-0001.jpeg',
#  'NORMAL2-IM-0500-0001.jpeg',
#  'NORMAL2-IM-0393-0001.jpeg',
#  'NORMAL2-IM-0994-0001.jpeg',
#  'IM-0207-0001.jpeg',
#  'IM-0494-0001.jpeg',
#  'IM-0177-0001.jpeg',
#  'IM-0388-0001.jpeg',
#  'IM-0341-0001.jpeg',
#  'IM-0355-0001.jpeg',
#  'IM-0449-0001.jpeg',
#  'IM-0480-0001.jpeg',
#  'NORMAL2-IM-1038-0001.jpeg',
#  'NORMAL2-IM-1348-0001.jpeg',
#  'IM-0739-0001.jpeg',
#  'IM-0213-0001.jpeg',
#  'NORMAL2-IM-0452-0001.jpeg',
#  'NORMAL2-IM-0980-0001.jpeg',
#  'NORMAL2-IM-0949-0001.jpeg',
#  'NORMAL2-IM-0664-0001.jpeg',
#  'NORMAL2-IM-1332-0001.jpeg',
#  'IM-0269-0001.jpeg',
#  'NORMAL2-IM-1104-0001.jpeg',
#  'IM-0575-0001.jpeg',
#  'IM-0605-0001.jpeg',
#  'NORMAL2-IM-1274-0001.jpeg',
# ...

# %%
random.shuffle(image_names)

# %%
for i in range(145):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH,image_name)
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("copying images",i)
# Out:
# copying images 0
# copying images 1
# copying images 2
# copying images 3
# copying images 4
# copying images 5
# copying images 6
# copying images 7
# copying images 8
# copying images 9
# copying images 10
# copying images 11
# copying images 12
# copying images 13
# copying images 14
# copying images 15
# copying images 16
# copying images 17
# copying images 18
# copying images 19
# copying images 20
# copying images 21
# copying images 22
# copying images 23
# copying images 24
# copying images 25
# copying images 26
# copying images 27
# copying images 28
# copying images 29
# copying images 30
# copying images 31
# copying images 32
# copying images 33
# copying images 34
# copying images 35
# copying images 36
# copying images 37
# copying images 38
# copying images 39
# copying images 40
# copying images 41
# copying images 42
# copying images 43
# copying images 44
# copying images 45
# copying images 46
# copying images 47
# copying images 48
# copying images 49
# ...
